# %%
import pandas as pd
import pymysql
from matplotlib import pyplot as plt
from matplotlib import font_manager, rc
import numpy as np
import chardet
import csv

# %%
import chardet
with open('./data/ytac.csv', 'rb') as rawdata:
    result = chardet.detect(rawdata.read(10000))
print(result)
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}

# %%
df = pd.read_csv("./data/ytac.csv", encoding="EUC-KR")

# %%
df_1 = pd.read_csv("./data/drunk_result.csv", encoding="EUC-KR")

# %%
df_1_index = df_1.set_index("month")

# %%
df_1_drop = df_1.drop([0], axis=0)

# %%
ax = df_1_drop.plot(
    kind="bar",
    figsize=(12, 6)
)

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    # print(p.get_bbox().bounds)
    ax.annotate("%i"%(height), (left+width/2, height*1.01), ha='center', size=5)

# %%
# 참고자료 : 통계청 가해자_음주정도별_주야별_교통사고_20240709111523
from matplotlib import pyplot as plt
from matplotlib import font_manager, rc
# AppleGothic
# Malgun Gothic
plt.rc("font", family="Malgun Gothic")

# plt.style.use("ggplot")
plt.figure(figsize=(12,6))
plt.title("2022년 월별 음주운전 교통사고 사망자 현황")
plt.xlabel("월")
plt.ylabel("수")
plt.plot(df_1_index.iloc[1:][["count_of_accident"]], label="사고수(명)", marker="o", markersize=5)
plt.plot(df_1_index.iloc[1:][["sum_of_death"]], label="사망자수(명)",  marker="o", markersize=5)
plt.plot(df_1_index.iloc[1:][["sum_of_injury"]], label="부상자수(명)",  marker="o", markersize=5)
plt.plot(df_1_index.iloc[1:][["sum_of_all"]], label="사상자수(명)", marker="o", markersize=5)
plt.legend()
_ = plt.xticks(size = 8, rotation=0, ha="center")

plt.grid(True)

x1 = df_1_drop["month"].tolist()
y1 = df_1_drop["count_of_accident"].tolist()
for i in range(len(x1)):
    height = y1[i]
    plt.text(x1[i], height + 0.25, '%i' %height, ha='center', va='bottom', size = 8)


x2 = df_1_drop["month"].tolist()
y2 = df_1_drop["sum_of_death"].tolist()
for i in range(len(x2)):
    height = y2[i]
    plt.text(x2[i], height + 0.25, '%i' %height, ha='center', va='bottom', size = 8)

# x3 = df_1_drop["month"].tolist()
# y3 = df_1_drop["sum_of_injury"].tolist()
# for i in range(len(x3)):
#     height = y3[i]
#     plt.text(x3[i], height + 0.25, '%i' %height, ha='center', va='bottom', size = 8)

x4 = df_1_drop["month"].tolist()
y4 = df_1_drop["sum_of_all"].tolist()
for i in range(len(x4)):
    height = y4[i]
    plt.text(x4[i], height + 0.25, '%i' %height, ha='center', va='bottom', size = 8)

# %%
import pandas as pd
df_22 = pd.read_csv("./data/people.csv", encoding = 'EUC-KR')

# %%
df_22_setindex = df_22.set_index(["Unnamed: 0"])

# %%
df_22_drop = df_22_setindex[["2022"]]

# %%
df_22_sort = df_22_drop.sort_values(by =["2022"], ascending=False)

# %%
df_22_drop2 = df_22_sort.drop(["계"], axis=0)

# %%
df_22_drop3 = df_22_drop2.drop(["수도권"], axis=0)

# %%
from matplotlib import font_manager, rc

from matplotlib import pyplot as plt
# AppleGothic
# Malgun Gothic
plt.rc("font", family="Malgun Gothic")

ax = df_22_drop3.plot(
        kind="bar",
        figsize=(12, 6)
)
_ = plt.xticks(size = 8, rotation=0, ha="center")

plt.xlabel("지역")
plt.ylabel("인구수")

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    # print(p.get_bbox().bounds)
    ax.annotate("%i"%(height), (left+width/2, height*1.01), ha='center', size=8)

# %%
df_23_drop = df_22_setindex[["2023"]]

# %%
df_23_sort = df_23_drop.sort_values(by =["2023"], ascending=False)

# %%
df_23_drop2 = df_23_sort.drop(["계"], axis=0)

# %%
df_23_drop3 = df_23_drop2.drop(["수도권"], axis=0)

# %%
from matplotlib import font_manager, rc

from matplotlib import pyplot as plt
# AppleGothic
# Malgun Gothic
plt.rc("font", family="Malgun Gothic")

ax = df_23_drop3.plot(
        kind="bar",
        figsize=(12, 6)
)
_ = plt.xticks(size = 8, rotation=0, ha="center")

plt.xlabel("지역")
plt.ylabel("인구수")

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    # print(p.get_bbox().bounds)
    ax.annotate("%i"%(height), (left+width/2, height*1.01), ha='center', size=8)

# %%
import pandas as pd
df_26 = pd.read_csv("./data/weather.csv", encoding = 'EUC-KR')

# %%
df_26_drop = df_26[df_26["사고유형"] == "사고[건]"]

# %%
df_26_drop2 = df_26_drop.drop(["사고유형"], axis=1)

# %%
df_26_setindex = df_26_drop2.set_index(["연도"])

# %%
df_26_transpose = df_26_setindex.transpose()

# %%
df_26_transpose
# Out:
# 연도      2023
# 합계     39611
# 맑음     35309
# 흐림      1307
# 비       2484
# 안개        36
# 눈        104
# 기타/불명    371

# %%
from matplotlib import font_manager, rc

from matplotlib import pyplot as plt
# AppleGothic
# Malgun Gothic
plt.rc("font", family="Malgun Gothic")

ax = df_26_transpose.plot(
        kind="bar",
        figsize=(12, 6)
)
_ = plt.xticks(size = 8, rotation=0, ha="center")

plt.xlabel("날씨")
plt.ylabel("사고건수")

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    # print(p.get_bbox().bounds)
    ax.annotate("%i"%(height), (left+width/2, height*1.01), ha='center', size=8)

# %%
df_27_drop = df_26[df_26["사고유형"] == "사망[명]"]

# %%
df_27_drop2 = df_27_drop.drop(["사고유형"], axis=1)

# %%
df_27_setindex = df_27_drop2.set_index(["연도"])

# %%
df_27_transpose = df_27_setindex.transpose()

# %%
from matplotlib import font_manager, rc

from matplotlib import pyplot as plt
# AppleGothic
# Malgun Gothic
plt.rc("font", family="Malgun Gothic")

ax = df_27_transpose.plot(
        kind="bar",
        figsize=(12, 6)
)
_ = plt.xticks(size = 8, rotation=0, ha="center")

plt.xlabel("날씨")
plt.ylabel("사망자수")

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    # print(p.get_bbox().bounds)
    ax.annotate("%i"%(height), (left+width/2, height*1.01), ha='center', size=8)

# %%
df_28_drop = df_26[df_26["사고유형"] == "사상자[명]"]

# %%
df_28_drop2 = df_28_drop.drop(["사고유형"], axis=1)

# %%
df_28_setindex = df_28_drop2.set_index(["연도"])

# %%
df_28_transpose = df_28_setindex.transpose()

# %%
from matplotlib import font_manager, rc

from matplotlib import pyplot as plt
# AppleGothic
# Malgun Gothic
plt.rc("font", family="Malgun Gothic")

ax = df_28_transpose.plot(
        kind="bar",
        figsize=(12, 6)
)
_ = plt.xticks(size = 8, rotation=0, ha="center")

plt.xlabel("날씨")
plt.ylabel("사상자수")

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    # print(p.get_bbox().bounds)
    ax.annotate("%i"%(height), (left+width/2, height*1.01), ha='center', size=8)

# %%
import pandas as pd
df_29 = pd.read_csv("./data/accident.csv", encoding = 'EUC-KR')

# %%
df_29
# Out:
#     사고유형     합계  앞지르기방법위반  앞지르기금지위반  중앙선침범  신호위반  안전거리미확보  일시정지위반  부당한회전  \
# 0  사고[건]  39611        14        42   1766  4614     4670      87    339
# 1  사망[명]    745         1         2     62    54       19       0      6
# 2  부상[명]  56064        14        69   2997  7059     7172     143    431
#
#    우선권양보불이행  진로양보불이행  안전운전의무불이행  교차로운행방법위반  보행자보호의무위반  차로위반(진로변경)  직진우회전진행방해  \
# 0         1        7      21650       2389       1445         622       1070
# 1         0        0        530         13         20           0          4
# 2         1       10      29458       3538       1502         848       1667
#
#    긴급차피양의무위반    기타  정비불량
# 0          1   893     1
# 1          0    34     0
# 2          1  1149     5

# %%
df_29_drop = df_29[df_29["사고유형"] == "사고[건]"]

# %%
df_29_drop2 = df_29_drop.drop(["사고유형"], axis = 1)

# %%
df_29_drop3 = df_29_drop2.drop(["합계"], axis = 1)

# %%
df_29_transpose = df_29_drop3.transpose()

# %%
df_29_transpose.columns = ["2023"]

# %%
df_29_sort = df_29_transpose.sort_values(by = ["2023"], ascending=False)

# %%
from matplotlib import font_manager, rc

from matplotlib import pyplot as plt
# AppleGothic
# Malgun Gothic
plt.rc("font", family="Malgun Gothic")

ax = df_29_sort.plot(
        kind="bar",
        figsize=(12, 6)
)
_ = plt.xticks(size = 8, rotation=90, ha="center")

plt.xlabel("법규위반유형")
plt.ylabel("사고건수")

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    # print(p.get_bbox().bounds)
    ax.annotate("%i"%(height), (left+width/2, height*1.01), ha='center', size=8)

# %%
import pandas as pd
df_30 = pd.read_csv("./data/type.csv", encoding = 'EUC-KR')

# %%
df_30_drop = df_30.iloc[:3][["차대사람","차대차", "차량단독", "철길건널목"]]

# %%
df_30_astype1 = df_30_drop.astype({'차대사람':'int'})

# %%
df_30_astype2 = df_30_astype1.astype({'차대차':'int'})

# %%
df_30_astype3 = df_30_astype2.astype({'차량단독':'int'})

# %%
df_30_astype4 = df_30_astype3.astype({'철길건널목':'int'})

# %%
df_30_transpose = df_30_astype4.transpose()

# %%
df_30_transpose.columns = [["사고건수", "사망자수", "부상자수"]]

# %%
from matplotlib import font_manager, rc

from matplotlib import pyplot as plt
# AppleGothic
# Malgun Gothic
plt.rc("font", family="Malgun Gothic")

ax = df_30_transpose.plot(
        kind="bar",
        figsize=(12, 6)
)
_ = plt.xticks(size = 8, rotation=0, ha="center")

plt.xlabel("사고유형")
plt.ylabel("사고건수")

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    # print(p.get_bbox().bounds)
    ax.annotate("%i"%(height), (left+width/2, height*1.01), ha='center', size=8)

# %%
# https://kosis.kr/ KOSIS 국가 통계포털 : 연령별 시력 분포 현황 2022
import pandas as pd
df_30 = pd.read_csv("./data/eyes.csv", encoding = 'EUC-KR')
